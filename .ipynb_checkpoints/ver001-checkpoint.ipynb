# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from nltk.corpus import stopwords
from nltk.util import ngrams
from sklearn.feature_extraction.text import CountVectorizer
from collections import defaultdict
from collections import  Counter
plt.style.use('ggplot')
stop=set(stopwords.words('english'))
import re
from nltk.tokenize import word_tokenize
import gensim
import string
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from tqdm import tqdm
from keras.models import Sequential
from keras.layers import Embedding,LSTM,Dense,SpatialDropout1D
from keras.initializers import Constant
from sklearn.model_selection import train_test_split
from keras.optimizers import Adam
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from imblearn.ensemble import BalancedBaggingClassifier
from imblearn.under_sampling import RandomUnderSampler

# %%
pd.set_option('display.max_rows', 5000000)
pd.set_option('display.max_columns', 5000000)
pd.set_option('display.width', 10000000)
pd.set_option('display.max_colwidth', 4000)

# %%
train= pd.read_csv('train.csv')
test=pd.read_csv('test.csv')
target = train[["label"]]
df=pd.concat([train,test])
# Out:
# D:\ProgramFiles\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   after removing the cwd from sys.path.

# %%
df.drop(["label", "id"],axis=1,inplace=True)

# %%
df.head(500)
# Out:
#                                                                                                               tweet
# 0                                                        user father dysfunctional selfish drag kid dysfunction run
# 1                  user user thanks lyft credit cant use cause dont offer wheelchair van pdx disapointed getthanked
# 2                                                                                                    bihday majesty
# 3                                                                                     model love u take u time ur
# 4                                                                                     factsguide society motivation
# 5                                              huge fan fare big talking leave chaos pay dispute get allshowandnogo
# 6                                                    user camping tomorrow user user user user user user user danny
# 7                 next school year year exams cant think  school exam hate imagine actorslife revolutionschool girl
# 8                                                       love land allin cavs champion cleveland clevelandcavaliers
# 9                                                                                           user user welcome im gr
# 10                                     ireland consumer price index mom climbed previous may blog silver gold forex
# 11     selfish orlando standwithorlando pulseshooting orlandoshooting biggerproblems selfish heabreaking value love
# 12                                                                               get see daddy today day gettingfed
# 13                                                       user cnn call michigan middle school build wall chant tcot
# 14                             comment australia opkillingbay seashepherd helpcovedolphins thecove helpcovedolphins
# 15                                                                           ouchjunior angrygot junior yugyoem omg
# 16                                                                                 thankful paner thankful positive
# 17                                                                                                    retweet agree
# 18                                                          friday  smile around via ig user user cooky make people
# 19                                                                                 know essential oil made chemical
# 20                             euro people blaming ha conceded goal fat rooney gave away free kick knowing bale hit
# 21                                                        sad little dude badday coneofshame cat pissed funny laugh
# 22                                                  product day happy man wine tool who weekend time open amp drink
# 23                                                                                  user user lumpy say prove lumpy
# 24                                        user tgif ff gamedev indiedev indiegamedev squad user user user user user
# 25                                                           beautiful sign vendor upsideofflorida shopalyssas love
# 26                                         user smile medium  pressconference antalya turkey sunday throwback love
# 27                                                                     great panel mediatization public service ica
# 28                                                                                           happy father day user
# 29                           people went nightclub good night man action mean people lost family forever riporlando
# 30                                            never chance vote presidential candidate excited cycle look different
# 31                                                alohafriday time exist positivevibes hawaiian user user user user
# 32                 user rip fellow nohern ireland fan sadley passed away tonight gawa forever singing cheering fire
# 33                             hard monday due cloudy weather disabling oxygen production today goodnight badmonday
# 34                                              unbelievable st century wed need something like neverump xenophobia
# 35                                                            taylorswift bull dominate bull direct whatever want w
# 36                                                                           morning travelingram dalat ripinkylife
# 37                    user one word tell photoshop enoughisenough dontphotoshopeverything wheresallthenaturalphotos
# 38                                                     oh cedarpoint waited hour valravn line stopped working close
# 39                                                                              thankful sunshine thankful positive
# 485                                                      view th floor nyc newyorkcity myview girl wine fridaynight
# 486                                                  discussing republican thing critiquing cant ignore consequence
# 487                                                                            got school tomorrow last integration
# 488                                                                            amen truth always lt lt love blessed
# 489                                               user stamford kid got month rapebut wasnt boredomit minute action
# 490                                                   let colorized life w rainbow danian love colour rainbow depok
# 491           aiel aielmaharashtra rude customer care executive make want switch loyalty another provider irritated
# 492                                                                 hi teddy corpuz rocksteddy band enjoy idol omg
# 493                                            user wow great daughter send father right father day cheapshot shame
# 494                               reason happywhen kid midtantrum parenting tantrum toddler calm mindfulness strong
# 495                                                                               truthful iam positive affirmation
# 496                                                              yup siri macos wwdc woot next work listening skill
# 497                                                diy done dresser nicknack newelectricscrewdriver brockely london
# 498                                                               black amp feel like stomping  retweet tampa miami
# 499                            user user thats problem one police officer need bigger gun perhaps one tank soldiers

# %%
fig, axes = plt.subplots(ncols=2, figsize=(17, 4), dpi=100)
plt.tight_layout()

train.groupby('label').count()['id'].plot(kind='pie', ax=axes[0], labels=['Not Conflict', 'Conflict'])
sns.countplot(x=train['label'], hue=train['label'], ax=axes[1])

axes[0].set_ylabel('')
axes[1].set_ylabel('')
axes[1].set_xticklabels(['Not Conflict', 'Conflict'])
axes[0].tick_params(axis='x', labelsize=15)
axes[0].tick_params(axis='y', labelsize=15)
axes[1].tick_params(axis='x', labelsize=15)
axes[1].tick_params(axis='y', labelsize=15)

axes[0].set_title('Target Distribution in Training Set', fontsize=13)
axes[1].set_title('Target Count in Training Set', fontsize=13)

plt.show()

# %%
#buyuk-kucuk donusumu
df['tweet'] = df['tweet'].apply(lambda x: " ".join(x.lower() for x in x.split()))
#noktalama işaretleri
df['tweet'] = df['tweet'].str.replace('[^\w\s]','')
#sayılar
df['tweet'] = df['tweet'].str.replace('\d','')
#stopwords
import nltk
#nltk.download('stopwords')
from nltk.corpus import stopwords
sw = stopwords.words('english')
df['tweet'] = df['tweet'].apply(lambda x: " ".join(x for x in x.split() if x not in sw))
#seyreklerin silinmesi
sil = pd.Series(' '.join(df['tweet']).split()).value_counts()[-1000:]
df['tweet'] = df['tweet'].apply(lambda x: " ".join(x for x in x.split() if x not in sil))
#lemmi
from textblob import Word
#nltk.download('wordnet')
df['tweet'] = df['tweet'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))

# %%
def remove_emoji(text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

# %%
df['tweet']=df['tweet'].apply(lambda x: remove_emoji(x))

# %%
def remove_punct(text):
    table=str.maketrans('','',string.punctuation)
    return text.translate(table)

# %%
df['tweet']=df['tweet'].apply(lambda x : remove_punct(x))

# %%
def remove_URL(text):
    url = re.compile(r'https?://\S+|www\.\S+')
    return url.sub(r'',text)

# %%
df['tweet']=df['tweet'].apply(lambda x : remove_URL(x))

# %%
df["tweet"]=df["tweet"].str.replace("[ð½¼âï]","")

# %% [markdown]
# ### BURADA VERİ TEMİZLİĞİ BİTMİŞ OLDU#

# %%
train=df[:train.shape[0]]
test=df[train.shape[0]:]

# %%
train_x, test_x, train_y, test_y = train_test_split(train["tweet"],
                                                                   target["label"], 
                                                                    random_state = 1)

# %%
tf_idf_word_vectorizer = TfidfVectorizer()
tf_idf_word_vectorizer.fit_transform(train_x)
# Out:
# <23971x31152 sparse matrix of type '<class 'numpy.float64'>'
# 	with 185062 stored elements in Compressed Sparse Row format>

# %%
train_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23971 entries, 15552 to 29733
# Data columns (total 1 columns):
# tweet    23971 non-null object
# dtypes: object(1)
# memory usage: 374.5+ KB

# %%
x_train_tf_idf_word = tf_idf_word_vectorizer.transform(train_x)

# %%
x_test_tf_idf_word = tf_idf_word_vectorizer.transform(test_x)

# %%
np.shape(test)
# Out:
# (17197, 31152)

# %%
test = test["tweet"]
test = tf_idf_word_vectorizer.transform(test)

# %%
nb = MultinomialNB()
nb_model = nb.fit(x_train_tf_idf_word,train_y)
# Out:
# Word-Level TF-IDF Doğruluk Oranı: 0.8614511298638725

# %%
accuracy = cross_val_score(nb_model, 
                                           x_test_tf_idf_word, 
                                           test_y, scoring="roc_auc",
                                           cv = 10).mean()

print("Word-Level TF-IDF Doğruluk Oranı:", accuracy)
# Out:
# Word-Level TF-IDF Doğruluk Oranı: 0.8614511298638725

# %%
y_pred_nb = nb_model.predict(x_test_tf_idf_word)

# %%
confusion_matrix(test_y, y_pred)
# Out:
# array([[7450,    1],
#        [ 461,   79]], dtype=int64)

# %%
rf = RandomForestClassifier()
rf_model = rf.fit(x_train_tf_idf_word,train_y)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-101-fcbe70e97467> in <module>
#       4                                            x_test_tf_idf_word,
#       5                                            test_y, scoring="f1",
# ----> 6                                            cv = 3).mean()
#       7
#       8 print("Word-Level TF-IDF Doğruluk Oranı:", accuracy)
#
# D:\ProgramFiles\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     388                                 fit_params=fit_params,
#     389                                 pre_dispatch=pre_dispatch,
# --> 390                                 error_score=error_score)
#     391     return cv_results['test_score']
#     392
#
# D:\ProgramFiles\lib\site-packages\sklearn\model_selection\_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     234             return_times=True, return_estimator=return_estimator,
#     235             error_score=error_score)
# --> 236         for train, test in cv.split(X, y, groups))
#     237
#     238     zipped_scores = list(zip(*scores))
#
# D:\ProgramFiles\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#     919             # remaining jobs.
#     920             self._iterating = False
# --> 921             if self.dispatch_one_batch(iterator):
#     922                 self._iterating = self._original_iterator is not None
#     923
#
# D:\ProgramFiles\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# D:\ProgramFiles\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# D:\ProgramFiles\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# D:\ProgramFiles\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# D:\ProgramFiles\lib\site-packages\joblib\parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# D:\ProgramFiles\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# D:\ProgramFiles\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     513             estimator.fit(X_train, **fit_params)
#     514         else:
# --> 515             estimator.fit(X_train, y_train, **fit_params)
#     516
#     517     except Exception as e:
#
# D:\ProgramFiles\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     381                     verbose=self.verbose, class_weight=self.class_weight,
#     382                     n_samples_bootstrap=n_samples_bootstrap)
# --> 383                 for i, t in enumerate(trees))
#     384
#     385             # Collect newly grown trees
#
# D:\ProgramFiles\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#     922                 self._iterating = self._original_iterator is not None
#     923
# --> 924             while self.dispatch_one_batch(iterator):
#     925                 pass
#     926
#
# D:\ProgramFiles\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# D:\ProgramFiles\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# D:\ProgramFiles\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# D:\ProgramFiles\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# D:\ProgramFiles\lib\site-packages\joblib\parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# D:\ProgramFiles\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# D:\ProgramFiles\lib\site-packages\sklearn\ensemble\_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     163             curr_sample_weight *= compute_sample_weight('balanced', y, indices)
#     164
# --> 165         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     166     else:
#     167         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# D:\ProgramFiles\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     875             sample_weight=sample_weight,
#     876             check_input=check_input,
# --> 877             X_idx_sorted=X_idx_sorted)
#     878         return self
#     879
#
# D:\ProgramFiles\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     365                                            min_impurity_split)
#     366
# --> 367         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     368
#     369         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %%
accuracy = cross_val_score(rf_model, 
                                           x_test_tf_idf_word, 
                                           test_y, scoring="f1",
                                           cv = 3).mean()

print("Word-Level TF-IDF Doğruluk Oranı:", accuracy)
# Out:
# Word-Level TF-IDF Doğruluk Oranı: 0.38391758328848563

# %%
y_pred_rf = rf_model.predict(x_test_tf_idf_word)

# %%
confusion_matrix(test_y, y_pred_rf)
# Out:
# array([[7428,   23],
#        [ 279,  261]], dtype=int64)

# %%
submission=pd.read_csv('sample_submission.csv')

# %%
y_pred_rf=rf_model.predict(test)

# %%
np.shape(submission)
# Out:
# (17197, 2)

# %%
sub=pd.DataFrame({'id':submission['id'].values.tolist(),'label':y_pred_rf})

# %%
sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17197 entries, 0 to 17196
# Data columns (total 2 columns):
# id       17197 non-null int64
# label    17197 non-null int64
# dtypes: int64(2)
# memory usage: 268.8 KB

# %%
sub.to_csv('170620_1.csv',index=False)
